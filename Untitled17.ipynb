# %%
import pandas as pd

# %%
data = pd.read_csv('C:\\Users\\MRC\\Downloads\\train.csv\\train.csv')
# Out:
#           Id  carat        cut color clarity  depth  table  price     x     y  \
# 0          1   1.06      Ideal     I     SI2   61.8   57.0   4270  6.57  6.60
# 1          2   1.51    Premium     G    VVS2   60.9   58.0  15164  7.38  7.42
# 2          3   0.32      Ideal     F     VS2   61.3   56.0    828  4.43  4.41
# 3          4   0.53      Ideal     G     VS2   61.2   56.0   1577  5.19  5.22
# 4          5   0.70    Premium     H    VVS2   61.0   57.0   2596  5.76  5.72
# ...      ...    ...        ...   ...     ...    ...    ...    ...   ...   ...
# 43147  43148   0.52      Ideal     E     VS2   61.5   56.0   1760  5.16  5.18
# 43148  43149   0.72  Very Good     D     VS2   62.1   59.0   3016  5.70  5.73
# 43149  43150   0.44    Premium     I    VVS1   61.5   58.0    990  4.95  4.87
# 43150  43151   0.31    Premium     E     VS1   60.2   58.0    734  4.38  4.43
# 43151  43152   0.33      Ideal     G     VS2   61.2   55.0    743  4.49  4.46
#
#           z
# 0      4.07
# ...

# %%
data.head()
# Out:
#    Id  carat      cut color clarity  depth  table  price     x     y     z
# 0   1   1.06    Ideal     I     SI2   61.8   57.0   4270  6.57  6.60  4.07
# 1   2   1.51  Premium     G    VVS2   60.9   58.0  15164  7.38  7.42  4.51
# 2   3   0.32    Ideal     F     VS2   61.3   56.0    828  4.43  4.41  2.71
# 3   4   0.53    Ideal     G     VS2   61.2   56.0   1577  5.19  5.22  3.19
# 4   5   0.70  Premium     H    VVS2   61.0   57.0   2596  5.76  5.72  3.50

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43152 entries, 0 to 43151
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Id       43152 non-null  int64
#  1   carat    43152 non-null  float64
#  2   cut      43152 non-null  object
#  3   color    43152 non-null  object
#  4   clarity  43152 non-null  object
#  5   depth    43152 non-null  float64
#  6   table    43152 non-null  float64
#  7   price    43152 non-null  int64
#  8   x        43152 non-null  float64
#  9   y        43152 non-null  float64
#  10  z        43152 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 3.6+ MB

# %%
data.describe()
# Out:
#                  Id         carat         depth         table         price  \
# count  43152.000000  43152.000000  43152.000000  43152.000000  43152.000000
# mean   21576.500000      0.797855     61.747177     57.458347   3929.491912
# std    12457.053745      0.473594      1.435454      2.233904   3985.527795
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    10788.750000      0.400000     61.000000     56.000000    947.750000
# 50%    21576.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    32364.250000      1.040000     62.500000     59.000000   5312.000000
# max    43152.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  43152.000000  43152.000000  43152.000000
# mean       5.731568      5.735018      3.538568
# std        1.121279      1.148809      0.708238
# min        0.000000      0.000000      0.000000
# ...

# %%
data.isna().sum()
# Out:
# Id         0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
import matplotlib.pyplot as plt
data.hist(bins=50, figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'Id'}>,
#         <Axes: title={'center': 'carat'}>,
#         <Axes: title={'center': 'depth'}>],
#        [<Axes: title={'center': 'table'}>,
#         <Axes: title={'center': 'price'}>, <Axes: title={'center': 'x'}>],
#        [<Axes: title={'center': 'y'}>, <Axes: title={'center': 'z'}>,
#         <Axes: >]], dtype=object)

# %%
import seaborn as sns
# Discover and Visualize the Data to Gain Insights
# Visualizing Geographical Data
# Using a regression line to represent the relationship between price and weight, i.e. is there a relationship between price and weight?
sns.lmplot(x='carat', y='price', data=data)
plt.title('Regression Line: Carat vs. Price')
plt.xlabel('Carat')
plt.ylabel('Price')
plt.show()
# An ascending line indicates an upward/direct relationship. This indicates that diamonds with higher weights are usually more

# %%
# How does the price change with changes in color? Are there colors that have a higher value?
sns.barplot(x='color', y='price', data=data)
plt.title('Bar Plot: Color vs. Price')
plt.xlabel('Color')
plt.ylabel('Total Price')
plt.show()
# There is a variation in the distribution of 
# colors based on their price, as you noticed from the figure that some colors enjoy a higher price compared to others.
#Color I and J has price more than others

# %%
# Looking for Correlations
daimond_num= data.drop(['cut','clarity','color'],axis=1)
corr_matrix = daimond_num.corr()
corr_matrix
# Out:
#              Id     carat     depth     table     price         x         y  \
# Id     1.000000  0.001141 -0.000776 -0.000739 -0.001111 -0.000519  0.001660
# carat  0.001141  1.000000  0.023944  0.182889  0.921911  0.975760  0.947060
# depth -0.000776  0.023944  1.000000 -0.302794 -0.013137 -0.029601 -0.033354
# table -0.000739  0.182889 -0.302794  1.000000  0.128501  0.197342  0.184310
# price -0.001111  0.921911 -0.013137  0.128501  1.000000  0.885181  0.861354
# x     -0.000519  0.975760 -0.029601  0.197342  0.885181  1.000000  0.968954
# y      0.001660  0.947060 -0.033354  0.184310  0.861354  0.968954  1.000000
# z     -0.000981  0.948923  0.090834  0.150746  0.857665  0.965677  0.942670
#
#               z
# Id    -0.000981
# carat  0.948923
# depth  0.090834
# table  0.150746
# price  0.857665
# x      0.965677
# y      0.942670
# z      1.000000

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap of Diamond Factors')
plt.show()
# Correlation values ​​(numbers) show the strength of the relationship between factors. The correlation value ranges between -1 and 1, 
# where positive values ​​indicate a positive correlation and negative values ​​indicate a negative correlation.
# The closer the value is to 1 or -1, the stronger the correlation, and the closer to 0 the weaker the correlation.
#every value is positive (positive correlation)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
data['cut']=le.fit_transform(data['cut'])
data['color']=le.fit_transform(data['color'])
data['clarity']=le.fit_transform(data['clarity'])

# %%
data
# Out:
#           Id  carat  cut  color  clarity  depth  table  price     x     y  \
# 0          1   1.06    2      5        3   61.8   57.0   4270  6.57  6.60
# 1          2   1.51    3      3        7   60.9   58.0  15164  7.38  7.42
# 2          3   0.32    2      2        5   61.3   56.0    828  4.43  4.41
# 3          4   0.53    2      3        5   61.2   56.0   1577  5.19  5.22
# 4          5   0.70    3      4        7   61.0   57.0   2596  5.76  5.72
# ...      ...    ...  ...    ...      ...    ...    ...    ...   ...   ...
# 43147  43148   0.52    2      1        5   61.5   56.0   1760  5.16  5.18
# 43148  43149   0.72    4      0        5   62.1   59.0   3016  5.70  5.73
# 43149  43150   0.44    3      5        6   61.5   58.0    990  4.95  4.87
# 43150  43151   0.31    3      1        4   60.2   58.0    734  4.38  4.43
# 43151  43152   0.33    2      3        5   61.2   55.0    743  4.49  4.46
#
#           z
# 0      4.07
# 1      4.51
# 2      2.71
# 3      3.19
# ...

# %%
x = data.drop('price',axis=1)
y=data['price']

# %%
x
# Out:
#           Id  carat  cut  color  clarity  depth  table     x     y     z
# 0          1   1.06    2      5        3   61.8   57.0  6.57  6.60  4.07
# 1          2   1.51    3      3        7   60.9   58.0  7.38  7.42  4.51
# 2          3   0.32    2      2        5   61.3   56.0  4.43  4.41  2.71
# 3          4   0.53    2      3        5   61.2   56.0  5.19  5.22  3.19
# 4          5   0.70    3      4        7   61.0   57.0  5.76  5.72  3.50
# ...      ...    ...  ...    ...      ...    ...    ...   ...   ...   ...
# 43147  43148   0.52    2      1        5   61.5   56.0  5.16  5.18  3.18
# 43148  43149   0.72    4      0        5   62.1   59.0  5.70  5.73  3.55
# 43149  43150   0.44    3      5        6   61.5   58.0  4.95  4.87  3.02
# 43150  43151   0.31    3      1        4   60.2   58.0  4.38  4.43  2.65
# 43151  43152   0.33    2      3        5   61.2   55.0  4.49  4.46  2.74
#
# [43152 rows x 10 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mxc = MinMaxScaler()

# %%
x_scl = mxc.fit_transform(x)

# %%
x_scl
# Out:
# array([[0.00000000e+00, 1.78794179e-01, 5.00000000e-01, ...,
#         6.11731844e-01, 1.12054329e-01, 1.27987421e-01],
#        [2.31744340e-05, 2.72349272e-01, 7.50000000e-01, ...,
#         6.87150838e-01, 1.25976231e-01, 1.41823899e-01],
#        [4.63488679e-05, 2.49480249e-02, 5.00000000e-01, ...,
#         4.12476723e-01, 7.48726655e-02, 8.52201258e-02],
#        ...,
#        [9.99953651e-01, 4.98960499e-02, 7.50000000e-01, ...,
#         4.60893855e-01, 8.26825127e-02, 9.49685535e-02],
#        [9.99976826e-01, 2.28690229e-02, 7.50000000e-01, ...,
#         4.07821229e-01, 7.52122241e-02, 8.33333333e-02],
#        [1.00000000e+00, 2.70270270e-02, 5.00000000e-01, ...,
#         4.18063315e-01, 7.57215620e-02, 8.61635220e-02]])

# %%
x_scl.shape
# Out:
# (43152, 10)

# %%
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import r2_score

# %%
lr=LinearRegression ()

# %%
lr.fit(x_scl,y)
preds = lr.predict(x_scl) 
print('r2 score ',r2_score(y,preds))
# Out:
# r2 score  0.8860772173451809

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures (degree=3)

# %%
x_poly = poly.fit_transform(x_scl)

# %%
x_scaled_poly = mxc.fit_transform(x_poly)

# %%
lr.fit(x_scaled_poly,y)
preds = lr.predict(x_scaled_poly) 
print('r2 score ',r2_score(y,preds))
# Out:
# r2 score  0.9440233591265299

# %%
from sklearn.model_selection import train_test_split

# %%
x
# Out:
#           Id  carat  cut  color  clarity  depth  table     x     y     z
# 0          1   1.06    2      5        3   61.8   57.0  6.57  6.60  4.07
# 1          2   1.51    3      3        7   60.9   58.0  7.38  7.42  4.51
# 2          3   0.32    2      2        5   61.3   56.0  4.43  4.41  2.71
# 3          4   0.53    2      3        5   61.2   56.0  5.19  5.22  3.19
# 4          5   0.70    3      4        7   61.0   57.0  5.76  5.72  3.50
# ...      ...    ...  ...    ...      ...    ...    ...   ...   ...   ...
# 43147  43148   0.52    2      1        5   61.5   56.0  5.16  5.18  3.18
# 43148  43149   0.72    4      0        5   62.1   59.0  5.70  5.73  3.55
# 43149  43150   0.44    3      5        6   61.5   58.0  4.95  4.87  3.02
# 43150  43151   0.31    3      1        4   60.2   58.0  4.38  4.43  2.65
# 43151  43152   0.33    2      3        5   61.2   55.0  4.49  4.46  2.74
#
# [43152 rows x 10 columns]

# %%
y
# Out:
# 0         4270
# 1        15164
# 2          828
# 3         1577
# 4         2596
#          ...
# 43147     1760
# 43148     3016
# 43149      990
# 43150      734
# 43151      743
# Name: price, Length: 43152, dtype: int64

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
lr.fit(x_train,y_train)
train_preds = lr.predict(x_train) 
test_preds = lr.predict(x_test) 
print('r2 score ',r2_score(y_train,train_preds))
print('r2 score ',r2_score(y_test,test_preds))
# Out:
# r2 score  0.8882509058456503
# r2 score  0.8766543345117086

# %%
x_train,x_test,y_train,y_test = train_test_split(x_scaled_poly,y,test_size=0.2)

# %%
lr.fit(x_train,y_train)
train_preds = lr.predict(x_train) 
test_preds = lr.predict(x_test) 
print('r2 score ',r2_score(y_train,train_preds))
print('r2 score ',r2_score(y_test,test_preds))
# Out:
# r2 score  0.9444678869330604
# r2 score  0.9125794502454709
